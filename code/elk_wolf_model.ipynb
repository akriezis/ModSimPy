# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

# %%
def make_system(α, β, γ, δ):
    init = State(x=1, y=1)
    
    t0 = 0
    t_end =1999
    
    return System(init=init, t0=t0, t_end=t_end, α=α, β=β, γ=γ, δ=δ)

# %%
def update_func(state,t, system):
    unpack(system)
    
    x, y = state
    
    x += α*x - β*x*y
    y += δ*x*y - γ*y
    
    return State(x=x, y=y)

# %%
def run_simulation(system, update_func):
    """Runs a simulation of the system.
        
    system: System object
    update_func: function that updates state
    
    returns: TimeFrame
    """
    unpack(system)
    
    frame = TimeFrame(columns=init.index)
    frame.row[t0] = init
    
    for t in linrange(t0, t_end):
        frame.row[t+1] = update_func(frame.row[t], t, system)
    
    return frame

# %%
system = make_system(0.05, 0.1, 0.1, 0.1)
results = run_simulation(system, update_func)
# Out:
#              x         y
# 0            1         1
# 1         0.95     0.995
# 2     0.902975  0.985346
# 3     0.859149  0.971467
# 4     0.818643  0.953849
# 5     0.781489  0.933007
# 6      0.74765  0.909462
# 7     0.717037  0.883728
# 8     0.689522   0.85629
# 9     0.664955    0.8276
# 10    0.643171  0.798069
# 11       0.624  0.768062
# 12    0.607273  0.737898
# 13    0.592826  0.707853
# 14    0.580504  0.678159
# 15    0.570162  0.649009
# 16    0.561666  0.620561
# 17    0.554895  0.592939
# 18    0.549738  0.566241
# 19    0.546096  0.540539
# 20    0.543882  0.515884
# 21    0.543018  0.492309
# 22    0.543436  0.469832
# 23    0.545075  0.448458
# 24    0.547885  0.428183
# 25    0.551819  0.408993
# 26    0.556841  0.390868
# 27    0.562918  0.373784
# 28    0.570023  0.357712
# 29    0.578134  0.342621
# ...        ...       ...
# 1970  0.598007  0.314405
# 1971  0.609106  0.302115
# 1972  0.621159   0.29067
# 1973  0.634162  0.280036
# 1974  0.648111  0.270182
# 1975  0.663006  0.261077
# 1976  0.678847  0.252692
# 1977  0.695635  0.245001
# 1978  0.713374  0.237979
# 1979  0.732066  0.231603
# 1980  0.751714  0.225852
# 1981  0.772322   0.22071
# 1982  0.793892  0.216161
# 1983  0.816426  0.212193
# 1984  0.839923  0.208796
# 1985  0.864382  0.205965
# 1986  0.889798  0.203695
# 1987  0.916163  0.201987
# 1988  0.943466  0.200845
# 1989  0.971691  0.200277
# 1990   1.00081  0.200293
# 1991   1.03081   0.20091
# 1992   1.06164  0.202148
# 1993   1.09326  0.204034
# 1994   1.12562  0.206597
# 1995   1.15864  0.209874
# 1996   1.19226  0.213909
# 1997   1.22637  0.218752
# 1998   1.26086  0.224458
# 1999    1.2956  0.231093
#
# [2000 rows x 2 columns]

# %%
def plot_results(x, y):
    """Plot the results of a SIR model.
    
    x: TimeSeries
    y: TimeSeries
    """
    plot(x, '--', label='elks')
    plot(y, '-', label='wolfs')
    decorate(xlabel='Time (days)',
             ylabel='population')

# %%
plot_results(results.x, results.y)
